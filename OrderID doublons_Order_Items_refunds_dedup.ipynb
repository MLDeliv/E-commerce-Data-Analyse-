# %%
import pandas as pd
import numpy as np

# %%
df_order_item_refunds = pd.read_csv("../../MODULE 7 - Proje final/Toy store/order_item_refunds.csv")

# %%
df_item_refunds1 = df_order_item_refunds.copy()

# %%
df_item_refunds1.head()
# Out:
#    order_item_refund_id           created_at  order_item_id  order_id  \
# 0                     1  2012-04-06 11:32:43             57        57
# 1                     2  2012-04-13 01:09:43             74        74
# 2                     3  2012-04-15 07:03:48             71        71
# 3                     4  2012-04-17 20:00:37            118       118
# 4                     5  2012-04-22 20:53:49            116       116
#
#    refund_amount_usd
# 0              49.99
# 1              49.99
# 2              49.99
# 3              49.99
# 4              49.99

# %%
uplicate_orders  = df_item_refunds1[df_item_refunds1.duplicated(subset=['order_id'], keep=False)]

# %%
uplicate_orders
# Out:
#       order_item_refund_id          created_at  order_item_id  order_id  \
# 487                    488 2013-12-16 11:50:31           9407      9324
# 491                    492 2013-12-19 21:50:31           9406      9324
# 1045                  1046 2014-09-07 23:30:27          22767     19518
# 1104                  1105 2014-09-13 02:30:27          22768     19518
# 1123                  1124 2014-09-15 20:44:54          23227     19848
# 1179                  1180 2014-09-22 10:44:54          23226     19848
# 1323                  1324 2014-11-21 15:08:12          27964     23321
# 1337                  1338 2014-11-28 18:08:12          27965     23321
# 1349                  1350 2014-12-01 14:54:59          29530     24472
# 1398                  1399 2014-12-10 22:54:59          29531     24472
# 1504                  1505 2015-01-12 11:47:12          33000     27061
# 1525                  1526 2015-01-19 13:47:12          33001     27061
# ...

# %%
# Convertir created_at en datetime
df_item_refunds1['created_at'] = pd.to_datetime(df_item_refunds1['created_at'])

# Conserver le dernier remboursement par order_id
df_item_refunds1_dedup = df_item_refunds1.sort_values('created_at').groupby('order_id', as_index=False).last()

# %%
uplicate_orders1  = df_item_refunds1_dedup[df_item_refunds1_dedup.duplicated(subset=['order_id'], keep=False)]

# %%
uplicate_orders1
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_refund_id, created_at, order_item_id, refund_amount_usd]
# Index: []

# %%
# Exporter vers un nouveau fichier CSV
df_item_refunds1_dedup.to_csv('order_item_refunds_dedup.csv', index=False)
